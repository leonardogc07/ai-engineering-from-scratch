# %% [markdown]
# # Exercise 2: Complete Notebook Demo
# Loading CSV → DataFrame → Plot (Restart & Run All should work top-to-bottom)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load a public sample CSV (Iris dataset - classic & tiny)
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris.csv')

print("✅ DataFrame loaded successfully!")
display(df.head())
# Out:
# ✅ DataFrame loaded successfully!
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# Simple plot
plt.figure(figsize=(8,5))
plt.scatter(df['SepalLength'], df['SepalWidth'], c=df['Name'].astype('category').cat.codes)
plt.title('Iris Dataset - Sepal Length vs Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.grid(True)
plt.show()
