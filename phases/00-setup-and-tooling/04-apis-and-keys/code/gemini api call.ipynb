# %%
import os
from dotenv import load_dotenv, find_dotenv
import google.generativeai as genai

# Robust .env loading (works from any sub-folder)
load_dotenv(find_dotenv())

# Configure Gemini with your key
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

model = genai.GenerativeModel("gemini-2.5-flash")   # fast + free-tier friendly

response = model.generate_content(
    "Say hello to my AI Engineering from Scratch journey! 🚀"
)

print(response.text)
# Out:
# Hello there! What an exciting journey you're embarking on!
#
# "AI Engineering from Scratch" is an incredibly rewarding path. It means building a solid foundation, understanding the fundamentals, and eventually creating amazing things.
#
# Get ready for a fascinating adventure filled with learning, problem-solving, and a ton of 'aha!' moments. The world of AI is vast and full of potential, and starting from the ground up will give you a truly robust understanding.
#
# Best of luck, enjoy every step, and embrace the challenges – they're where the best learning happens! We're here to cheer you on! 🚀
